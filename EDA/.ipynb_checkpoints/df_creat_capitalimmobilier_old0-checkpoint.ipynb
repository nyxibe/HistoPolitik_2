# %% [markdown]
# ## <center>  Model Creat Dataframe CAPITAL IMMOBILIER [KP0]<br/></center>
# <a name="TOP"></a>
# - dev : nyx
# - Fichier CSV :  correspondance-code-insee-code-postal.csv</a>
#
# # Description Fichiers :
# Géolocaliations des communes de FRANCE
#
# # Synthese des Actions :
# 7 lignes absentes !!! saisie manuel dont une impoté pour code postal
#
# **<u>MENU</u>**
# - <a href="#Import">P0 : Import CSV</a>
# - <a href="#EDA">P1 : Mini EDA</a>
# - <a href="#Nan">P2 : Traitement des Nan</a>
# - <a href="#TRANSCO">P3 : Filtres et/ou calculs</a>
# - <a href="#EXPORT">P4 : EXPORT (/DATA/EXPORT_CSV/final_xxxxxxx.csv)</a>

# %% [markdown]
# PREFIXE FICHIER : KP0
# Structure :
#
#     dep
#     nomdep
#     codecommune
#     nomcommune
#     GEO_latitude
#     GEO_longitude
#     DBL_geo_point_2d
#     DBL_coderegion
#     DBL_nomregion
#     DBL_bug (1 pour les 7 lignes ajoutées à la main)
#
# ATTENTION
# NE PAS GARDER TOUTES LES COLONNES !!
# DBL_ si info importante pour eventuel calcul de % par exmple

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import zipfile
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
def df_creat(filename, df_dataframe):  
    df = df_dataframe[df_dataframe['filename'] == filename]
    if len(df) == 1:
        row = df.iloc[0]
        file = row['path']
        if os.path.exists(file):
            df_from_csv = pd.read_csv(file, encoding='utf-8', low_memory=False)
            return df_from_csv
        else:
            print('FICHIER NON TROUVE', file)
            return pd.DataFrame()
    else:
        print(f"filename: '{filename}' return size: {len(df)}")
        return pd.DataFrame()

# %%
csv_file_path = 'df_filtred.csv'
# Use pandas to read the CSV file into a DataFrame with UTF-8 encoding
df_cat = pd.read_csv(csv_file_path, encoding='utf-8')

# %%
df_cat.head(1)
# Out:
#                    category           filename comment  size  depart  \
# 0  Taille_agglo_commune_csv  codescommunes1999   codes     0       0
#
#    district  commune  canton  yyyy  \
# 0         0        1       0  1999
#
#                                                 path  codecommune
# 0  ../../ProjetCommun/DATA_SOURCES/HCP/Taille_agg...            1

# %% [markdown]
# ## <a name="Import"></a>Partie 0 : Import CSV&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <a href="#TOP">&uarr;</a>

# %%
df = df_creat('capitalimmobilier', df_cat)

# %%
df.shape
# Out:
# (5455409, 14)

# %%
df['tmp']=df['prixbien']

# %%
df.head(5)
# Out:
#    annee dep nomdep codecommune             nomcommune  plm  prixbien  \
# 0   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0   40000.0
# 1   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0   93000.0
# 2   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0  134750.0
# 3   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0  186820.0
# 4   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0  193000.0
#
#        prixm2  surface  surfaceterrain  codemaisonappartement datemutation  \
# 0   370.37036      108            1005                      1   2014-01-30
# 1   861.11108      108            1005                      1   2014-01-27
# 2  2173.38720       62             523                      1   2014-02-20
# 3  1569.91600      119            1087                      1   2014-07-03
# 4  1873.78640      103             833                      1   2014-07-07
#
#    novoie         voie       tmp
# 0     6.0  LES MURIERS   40000.0
# 1     6.0  LES MURIERS   93000.0
# 2  5001.0   MUNETVILLE  134750.0
# 3     5.0  LES MURIERS  186820.0
# 4  5172.0   MUNETVILLE  193000.0

# %%
for c in df : 
    print (c)
# Out:
# annee
# dep
# nomdep
# codecommune
# nomcommune
# plm
# prixbien
# prixm2
# surface
# surfaceterrain
# codemaisonappartement
# datemutation
# novoie
# voie
# tmp

# %%
df['annee'].min().min()
# Out:
# 2014

# %%
df['annee'].max().max()
# Out:
# 2021

# %%
2021-2014+1
# Out:
# 8

# %% [markdown]
# ## Creation 2 periodes

# %%
# SPLIT 2 periodes fonctions des elelections
df1 = df[df['annee'] < 2018]
df2 = df[df['annee'] >= 2018]

# %%
df1.shape,df2.shape,
# Out:
# ((2767929, 15), (2687480, 15))

# %%
df1.head(2)
# Out:
#    annee dep nomdep codecommune             nomcommune  plm  prixbien  \
# 0   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0   40000.0
# 1   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT    0   93000.0
#
#       prixm2  surface  surfaceterrain  codemaisonappartement datemutation  \
# 0  370.37036      108            1005                      1   2014-01-30
# 1  861.11108      108            1005                      1   2014-01-27
#
#    novoie         voie      tmp
# 0     6.0  LES MURIERS  40000.0
# 1     6.0  LES MURIERS  93000.0

# %%
df_group1 = df1.groupby(['dep', 'nomdep', 'codecommune', 'nomcommune', 'codemaisonappartement']).agg({
    'prixbien': 'sum',
    'surface': 'sum',
    'surfaceterrain': 'sum',
    'tmp': 'count'
}).reset_index()

# %%
df_group1.head(2)
# Out:
#   dep nomdep codecommune             nomcommune  codemaisonappartement  \
# 0  01    AIN       01001  ABERGEMENT-CLEMENCIAT                      1
# 1  01    AIN       01002    ABERGEMENT-DE-VAREY                      1
#
#      prixbien  surface  surfaceterrain  tmp
# 0  5190811.33     2960           29249   28
# 1  2442260.00     2091            7040   21

# %%
df_group1['KP0_prim2_P1'] = df_group1['prixbien'] / df_group1['surface']
df_group1.head(2)
# Out:
#   dep nomdep codecommune             nomcommune  codemaisonappartement  \
# 0  01    AIN       01001  ABERGEMENT-CLEMENCIAT                      1
# 1  01    AIN       01002    ABERGEMENT-DE-VAREY                      1
#
#      prixbien  surface  surfaceterrain  tmp  KP0_prim2_P1
# 0  5190811.33     2960           29249   28   1753.652476
# 1  2442260.00     2091            7040   21   1167.986609

# %%
df_group1 = df_group1.rename(columns={
    'codemaisonappartement' : 'KP0_MaisApart_P1',
    'prixbien': 'KP0_Pri_P1',
    'surface': 'KP0_Surf_P1',
    'surfaceterrain': 'KP0_SurfTer_P1',
    'tmp' : 'KP0_transac_P1'
})
df_group1.head(2)
# Out:
#   dep nomdep codecommune             nomcommune  KP0_MaisApart_P1  KP0_Pri_P1  \
# 0  01    AIN       01001  ABERGEMENT-CLEMENCIAT                 1  5190811.33
# 1  01    AIN       01002    ABERGEMENT-DE-VAREY                 1  2442260.00
#
#    KP0_Surf_P1  KP0_SurfTer_P1  KP0_transac_P1  KP0_prim2_P1
# 0         2960           29249              28   1753.652476
# 1         2091            7040              21   1167.986609

# %%
df_group2 = df2.groupby(['dep', 'nomdep', 'codecommune', 'nomcommune', 'codemaisonappartement']).agg({
    'prixbien': 'sum',
    'surface': 'sum',
    'surfaceterrain': 'sum',
    'tmp' : 'count'
}).reset_index()

# PRIX / m2
df_group2['KP0_prim2_P2'] = df_group2['prixbien'] / df_group2['surface']

# RENAME
df_group2 = df_group2.rename(columns={
    'codemaisonappartement' : 'KP0_MaisApart_P2',
    'prixbien': 'KP0_Pri_P2',
    'surface': 'KP0_Surf_P2',
    'surfaceterrain': 'KP0_SurfTer_P2',
    'tmp' : 'KP0_transac_P2'
})

df_group2.head(2)
# Out:
#   dep nomdep codecommune             nomcommune  KP0_MaisApart_P2  KP0_Pri_P2  \
# 0  01    AIN       01001  ABERGEMENT-CLEMENCIAT                 1   5396090.0
# 1  01    AIN       01002    ABERGEMENT-DE-VAREY                 1   1885119.0
#
#    KP0_Surf_P2  KP0_SurfTer_P2  KP0_transac_P2  KP0_prim2_P2
# 0         2831           19871              24   1906.072059
# 1         1515            5858              15   1244.302970

# %%
df_result = pd.merge(df_group1, df_group2, on=['dep', 'nomdep', 'codecommune', 'nomcommune'], how='outer')

# Fill NaN values with 0
df_result = df_result.fillna(0)

# %%
df_result.head(10)
# Out:
#   dep nomdep codecommune             nomcommune  KP0_MaisApart_P1  \
# 0  01    AIN       01001  ABERGEMENT-CLEMENCIAT               1.0
# 1  01    AIN       01002    ABERGEMENT-DE-VAREY               1.0
# 2  01    AIN       01004      AMBERIEU-EN-BUGEY               1.0
# 3  01    AIN       01004      AMBERIEU-EN-BUGEY               1.0
# 4  01    AIN       01004      AMBERIEU-EN-BUGEY               2.0
# 5  01    AIN       01004      AMBERIEU-EN-BUGEY               2.0
# 6  01    AIN       01005    AMBERIEUX-EN-DOMBES               1.0
# 7  01    AIN       01005    AMBERIEUX-EN-DOMBES               1.0
# 8  01    AIN       01005    AMBERIEUX-EN-DOMBES               2.0
# 9  01    AIN       01005    AMBERIEUX-EN-DOMBES               2.0
#
#     KP0_Pri_P1  KP0_Surf_P1  KP0_SurfTer_P1  KP0_transac_P1  KP0_prim2_P1  \
# 0   5190811.33       2960.0         29249.0            28.0   1753.652476
# 1   2442260.00       2091.0          7040.0            21.0   1167.986609
# 2  69380300.00      37577.0        169830.0           377.0   1846.350161
# 3  69380300.00      37577.0        169830.0           377.0   1846.350161
# 4  35125226.84      17871.0          1971.0           272.0   1965.487485
# 5  35125226.84      17871.0          1971.0           272.0   1965.487485
# 6  11751503.00       6522.0         30471.0            58.0   1801.825054
# 7  11751503.00       6522.0         30471.0            58.0   1801.825054
# 8   5541023.01       2809.0          6115.0            35.0   1972.596301
# 9   5541023.01       2809.0          6115.0            35.0   1972.596301
#
#    KP0_MaisApart_P2    KP0_Pri_P2  KP0_Surf_P2  KP0_SurfTer_P2  \
# 0               1.0  5.396090e+06       2831.0         19871.0
# 1               1.0  1.885119e+06       1515.0          5858.0
# 2               1.0  8.374780e+07      38620.0        161976.0
# 3               2.0  3.915300e+07      20975.0          1244.0
# 4               1.0  8.374780e+07      38620.0        161976.0
# 5               2.0  3.915300e+07      20975.0          1244.0
# 6               1.0  1.423791e+07       6959.0         33946.0
# 7               2.0  3.771866e+06       1637.0             0.0
# 8               1.0  1.423791e+07       6959.0         33946.0
# 9               2.0  3.771866e+06       1637.0             0.0
#
#    KP0_transac_P2  KP0_prim2_P2
# 0            24.0   1906.072059
# 1            15.0   1244.302970
# 2           393.0   2168.508650
# 3           318.0   1866.650825
# 4           393.0   2168.508650
# 5           318.0   1866.650825
# 6            60.0   2045.970983
# 7            23.0   2304.133170
# 8            60.0   2045.970983
# 9            23.0   2304.133170

# %%
result_df = df.groupby(['annee', 'dep', 'nomdep', 'codecommune', 'nomcommune', 'codemaisonappartement']).agg({
    'prixbien': 'sum',
    'surface': 'sum',
    'surfaceterrain': 'sum'
}).reset_index()

# %%
result_df.head(5)
# Out:
#    annee dep nomdep codecommune             nomcommune  codemaisonappartement  \
# 0   2014  01    AIN       01001  ABERGEMENT-CLEMENCIAT                      1
# 1   2014  01    AIN       01002    ABERGEMENT-DE-VAREY                      1
# 2   2014  01    AIN       01004      AMBERIEU-EN-BUGEY                      1
# 3   2014  01    AIN       01004      AMBERIEU-EN-BUGEY                      2
# 4   2014  01    AIN       01005    AMBERIEUX-EN-DOMBES                      1
#
#       prixbien  surface  surfaceterrain
# 0   1529570.00      924            8419
# 1    323790.00      241             908
# 2  14304542.00     8013           38726
# 3   7727418.84     3634               0
# 4   1769336.00      883            4482

# %%
# Group by specified columns and calculate sums
result_df = df.groupby(['annee', 'dep', 'nomdep', 'codecommune', 'nomcommune', 'codemaisonappartement']).agg({
    'prixbien': 'sum',
    'surface': 'sum',
    'surfaceterrain': 'sum'
}).reset_index()

# Replace 'annee' values with two periods
result_df['annee'] = np.where(result_df['annee'] < 2018, '<2018', '>2017')

# %%
result_df.head(5)
# Out:
#    annee dep nomdep codecommune             nomcommune  codemaisonappartement  \
# 0  <2018  01    AIN       01001  ABERGEMENT-CLEMENCIAT                      1
# 1  <2018  01    AIN       01002    ABERGEMENT-DE-VAREY                      1
# 2  <2018  01    AIN       01004      AMBERIEU-EN-BUGEY                      1
# 3  <2018  01    AIN       01004      AMBERIEU-EN-BUGEY                      2
# 4  <2018  01    AIN       01005    AMBERIEUX-EN-DOMBES                      1
#
#       prixbien  surface  surfaceterrain
# 0   1529570.00      924            8419
# 1    323790.00      241             908
# 2  14304542.00     8013           38726
# 3   7727418.84     3634               0
# 4   1769336.00      883            4482

# %%
df2[df2['Code INSEE']=='78575']
# Out:
#       Code INSEE Code Postal                   Commune   Département  \
# 14060      78575       78470  SAINT-REMY-LES-CHEVREUSE  ['YVELINES']
#
#                   Région              Statut  Altitude Moyenne  Superficie  \
# 14060  ['ILE-DE-FRANCE']  ['Commune simple']             121.0       985.0
#
#        Population                          geo_point_2d  \
# 14060         8.0  48.70387375796769, 2.078989249560592
#
#                                                geo_shape  ID Geofla  \
# 14060  {"coordinates": [[[2.082078805055938, 48.68545...      16358
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 14060           575            5                    2               78
#
#        Code Région
# 14060           11

# %%
df2['dep'] = df2['Code Département']
df2['nomdep'] = df2['Département'].str.strip('[\'\']')  
df2[df2['Code INSEE']=='78575']
# Out:
#       Code INSEE Code Postal                   Commune   Département  \
# 14060      78575       78470  SAINT-REMY-LES-CHEVREUSE  ['YVELINES']
#
#                   Région              Statut  Altitude Moyenne  Superficie  \
# 14060  ['ILE-DE-FRANCE']  ['Commune simple']             121.0       985.0
#
#        Population                          geo_point_2d  \
# 14060         8.0  48.70387375796769, 2.078989249560592
#
#                                                geo_shape  ID Geofla  \
# 14060  {"coordinates": [[[2.082078805055938, 48.68545...      16358
#
#        Code Commune  Code Canton  Code Arrondissement Code Département  \
# 14060           575            5                    2               78
#
#        Code Région dep    nomdep
# 14060           11  78  YVELINES

# %%
df2['codecommune'] = df2['Code INSEE'].astype(str).str.zfill(5)
df2['nomcommune'] = df2['Commune'] 
df2[df2['Code INSEE']=='78575']
# Out:
#       Code INSEE Code Postal                   Commune   Département  \
# 14060      78575       78470  SAINT-REMY-LES-CHEVREUSE  ['YVELINES']
#
#                   Région              Statut  Altitude Moyenne  Superficie  \
# 14060  ['ILE-DE-FRANCE']  ['Commune simple']             121.0       985.0
#
#        Population                          geo_point_2d  ... ID Geofla  \
# 14060         8.0  48.70387375796769, 2.078989249560592  ...     16358
#
#        Code Commune  Code Canton  Code Arrondissement  Code Département  \
# 14060           575            5                    2                78
#
#       Code Région  dep    nomdep codecommune                nomcommune
# 14060          11   78  YVELINES       78575  SAINT-REMY-LES-CHEVREUSE
#
# [1 rows x 21 columns]

# %%
df2[['GEO_latitude', 'GEO_longitude']] = df2['geo_point_2d'].str.split(', ', expand=True)
df2[df2['Code INSEE']=='78575']
# Out:
#       Code INSEE Code Postal                   Commune   Département  \
# 14060      78575       78470  SAINT-REMY-LES-CHEVREUSE  ['YVELINES']
#
#                   Région              Statut  Altitude Moyenne  Superficie  \
# 14060  ['ILE-DE-FRANCE']  ['Commune simple']             121.0       985.0
#
#        Population                          geo_point_2d  ... Code Canton  \
# 14060         8.0  48.70387375796769, 2.078989249560592  ...           5
#
#        Code Arrondissement  Code Département  Code Région  dep    nomdep  \
# 14060                    2                78           11   78  YVELINES
#
#        codecommune                nomcommune       GEO_latitude  \
# 14060        78575  SAINT-REMY-LES-CHEVREUSE  48.70387375796769
#
#            GEO_longitude
# 14060  2.078989249560592
#
# [1 rows x 23 columns]

# %%
df2[['GEO_latitude', 'GEO_longitude']] = df2[['GEO_latitude', 'GEO_longitude']].apply(pd.to_numeric)
df2['DBL_geo_point_2d'] = df2['geo_point_2d'] 
df2['DBL_coderegion'] = df2['Code Région'] 
df2['DBL_nomregion'] = df2['Région'].str.strip('[\'\']') 
df2[df2['Code INSEE']=='78575']
# Out:
#       Code INSEE Code Postal                   Commune   Département  \
# 14060      78575       78470  SAINT-REMY-LES-CHEVREUSE  ['YVELINES']
#
#                   Région              Statut  Altitude Moyenne  Superficie  \
# 14060  ['ILE-DE-FRANCE']  ['Commune simple']             121.0       985.0
#
#        Population                          geo_point_2d  ... Code Région  dep  \
# 14060         8.0  48.70387375796769, 2.078989249560592  ...          11   78
#
#          nomdep  codecommune                nomcommune GEO_latitude  \
# 14060  YVELINES        78575  SAINT-REMY-LES-CHEVREUSE    48.703874
#
#        GEO_longitude                      DBL_geo_point_2d DBL_coderegion  \
# 14060       2.078989  48.70387375796769, 2.078989249560592             11
#
#        DBL_nomregion
# 14060  ILE-DE-FRANCE
#
# [1 rows x 26 columns]

# %%
for i,c in enumerate(df2) :
    print (i,c)
# Out:
# 0 Code INSEE
# 1 Code Postal
# 2 Commune
# 3 Département
# 4 Région
# 5 Statut
# 6 Altitude Moyenne
# 7 Superficie
# 8 Population
# 9 geo_point_2d
# 10 geo_shape
# 11 ID Geofla
# 12 Code Commune
# 13 Code Canton
# 14 Code Arrondissement
# 15 Code Département
# 16 Code Région
# 17 dep
# 18 nomdep
# 19 codecommune
# 20 nomcommune
# 21 GEO_latitude
# 22 GEO_longitude
# 23 DBL_geo_point_2d
# 24 DBL_coderegion
# 25 DBL_nomregion

# %%
df2 = df2.drop(df2.columns[:17], axis=1)
df2.head(10)
# Out:
#   dep           nomdep codecommune                nomcommune  GEO_latitude  \
# 0  59             NORD       59416                 MORBECQUE     50.676893
# 1  22  "COTES-D'ARMOR"       22102                 LANGOURLA     48.284641
# 2  31    HAUTE-GARONNE       31225             GOUTEVERNISSE     43.214026
# 3  23           CREUSE       23025                    BONNAT     46.323019
# 4  38            ISERE       38522               VALJOUFFREY     44.881535
# 5  21      "COTE-D'OR"       21249                  ESBARRES     47.091069
# 6  62    PAS-DE-CALAIS       62893                  WIMEREUX     50.779250
# 7  60             OISE       60331                   LABOSSE     49.354078
# 8  62    PAS-DE-CALAIS       62625     NOYELLES-LES-HUMIERES     50.375424
# 9  34          HERAULT       34277  SAINT-MAURICE-NAVACELLES     43.844873
#
#    GEO_longitude                        DBL_geo_point_2d  DBL_coderegion  \
# 0       2.536216    50.67689342861573, 2.536216144331492              31
# 1      -2.415501  48.284641107667674, -2.415501011324659              53
# 2       1.173766   43.214026301449536, 1.173765920286677              73
# 3       1.913451    46.32301933418213, 1.913450631364578              74
# 4       6.079504     44.88153491127053, 6.07950399615059              82
# 5       5.198247   47.091069454325485, 5.198246639283228              26
# 6       1.613432    50.77924978918239, 1.613432313096119              31
# 7       1.898320    49.35407816266846, 1.898320236754994              22
# 8       2.177378   50.37542375047368, 2.1773776418561592              31
# 9       3.506265    43.84487342385136, 3.506265066900079              91
#
#           DBL_nomregion
# 0    NORD-PAS-DE-CALAIS
# 1              BRETAGNE
# 2         MIDI-PYRENEES
# 3              LIMOUSIN
# 4           RHONE-ALPES
# 5             BOURGOGNE
# 6    NORD-PAS-DE-CALAIS
# 7              PICARDIE
# 8    NORD-PAS-DE-CALAIS
# 9  LANGUEDOC-ROUSSILLON

# %%
df2.dtypes
# Out:
# dep                  object
# nomdep               object
# codecommune          object
# nomcommune           object
# GEO_latitude        float64
# GEO_longitude       float64
# DBL_geo_point_2d     object
# DBL_coderegion        int64
# DBL_nomregion        object
# dtype: object

# %%
df2['codecommune'] = df2['codecommune'].astype(str).str.zfill(5)
df2.dtypes
# Out:
# dep                  object
# nomdep               object
# codecommune          object
# nomcommune           object
# GEO_latitude        float64
# GEO_longitude       float64
# DBL_geo_point_2d     object
# DBL_coderegion        int64
# DBL_nomregion        object
# dtype: object

# %%
df2[df2['codecommune']=='07060']
# Out:
#    dep   nomdep codecommune              nomcommune  GEO_latitude  \
# 16  07  ARDECHE       07060  CHATEAUNEUF-DE-VERNOUX     44.924924
#
#     GEO_longitude                      DBL_geo_point_2d  DBL_coderegion  \
# 16       4.642191  44.92492404782045, 4.642191100324167              82
#
#    DBL_nomregion
# 16   RHONE-ALPES

# %% [markdown]
# ## <a name="EDA"></a>Partie 1 : Mini EDA &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; <a href="#TOP">&uarr;</a>

# %% [markdown]
# ## <a name="Nan"></a>Partie 2 : Traitement des Nan&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#TOP">&uarr;</a>

# %%
codecommune_listdf2 = df2['codecommune'].tolist()
codecommune_listdf2[1]
# Out:
# '22102'

# %%
# Specify the file path
file_path = '../DATA/list_codecommune_leg2022_50inscrits.txt'

# Open the text file and read lines into a list
with open(file_path, 'r', encoding='utf-8') as file:
    lines = [line.strip() for line in file.readlines()]

# Print or manipulate the list of lines as needed
print(lines[0:10], len(lines))
# Out:
# ['01001', '01002', '01004', '01005', '01006', '01007', '01008', '01009', '01010', '01011'] 33830

# %%
absent = [x for x in lines if x not in codecommune_listdf2]

# %%
len(absent)
# Out:
# 7

# %%
absent
# Out:
# ['13055', '55138', '69123', '69380', '75056', '76095', '76601']

# %% [markdown]
# ### ['13055', '55138', '69123', '69380', '75056', '76095', '76601']

# %%
df2[df2['codecommune'] == '13055']
# Out:
# Empty DataFrame
# Columns: [dep, nomdep, codecommune, nomcommune, GEO_latitude, GEO_longitude, DBL_geo_point_2d, DBL_coderegion, DBL_nomregion]
# Index: []

# %%
df2[df2['nomcommune'].str.startswith('MARSEILL')]
# Out:
#       dep            nomdep codecommune                     nomcommune  \
# 648    60              OISE       60387        MARSEILLE-EN-BEAUVAISIS
# 1012   18              CHER       18139         MARSEILLES-LES-AUBIGNY
# 1474   13  BOUCHES-DU-RHONE       13207  MARSEILLE--7E--ARRONDISSEMENT
# 2280   13  BOUCHES-DU-RHONE       13203  MARSEILLE--3E--ARRONDISSEMENT
# 2320   13  BOUCHES-DU-RHONE       13211  MARSEILLE-11E--ARRONDISSEMENT
# 5868   13  BOUCHES-DU-RHONE       13206  MARSEILLE--6E--ARRONDISSEMENT
# 10395  13  BOUCHES-DU-RHONE       13209  MARSEILLE--9E--ARRONDISSEMENT
# 12718  13  BOUCHES-DU-RHONE       13213  MARSEILLE-13E--ARRONDISSEMENT
# 12724  34           HERAULT       34150                     MARSEILLAN
# 16604  13  BOUCHES-DU-RHONE       13212  MARSEILLE-12E--ARRONDISSEMENT
# 19675  13  BOUCHES-DU-RHONE       13216  MARSEILLE-16E--ARRONDISSEMENT
# 23614  13  BOUCHES-DU-RHONE       13205  MARSEILLE--5E--ARRONDISSEMENT
# 24406  13  BOUCHES-DU-RHONE       13210  MARSEILLE-10E--ARRONDISSEMENT
# 24737  13  BOUCHES-DU-RHONE       13208  MARSEILLE--8E--ARRONDISSEMENT
# 29315  13  BOUCHES-DU-RHONE       13214  MARSEILLE-14E--ARRONDISSEMENT
# 29768  13  BOUCHES-DU-RHONE       13202  MARSEILLE--2E--ARRONDISSEMENT
# 30562  65   HAUTES-PYRENEES       65301                     MARSEILLAN
# 31041  32              GERS       32238                     MARSEILLAN
# 31320  13  BOUCHES-DU-RHONE       13204  MARSEILLE--4E--ARRONDISSEMENT
# 31432  13  BOUCHES-DU-RHONE       13215  MARSEILLE-15E--ARRONDISSEMENT
# 31526  13  BOUCHES-DU-RHONE       13201  MARSEILLE--1ER-ARRONDISSEMENT
# 36463  11              AUDE       11220                   MARSEILLETTE
#
#        GEO_latitude  GEO_longitude                         DBL_geo_point_2d  \
# 648       49.575320       1.957650    49.57531958518338, 1.9576501987936932
# 1012      47.070038       2.993932     47.07003840293559, 2.993931525604912
# 1474      43.282518       5.363234     43.28251778002546, 5.363234404349721
# 2280      43.312120       5.380110     43.31212000462484, 5.380109814230027
# 2320      43.288447       5.483815    43.288447188052245, 5.483814662290308
# 5868      43.287099       5.381048     43.28709895455135, 5.381047853938594
# 10395     43.234083       5.452497     43.23408349271835, 5.452496830665194
# 12718     43.349278       5.433722     43.34927800054508, 5.433722387381286
# 12724     43.360578       3.547190    43.360577600709114, 3.547189637605787
# 16604     43.307768       5.439916     43.30776836776201, 5.439915676783301
# 19675     43.364905       5.313378    43.364905412122766, 5.313378285945362
# 23614     43.292806       5.397577     43.29280619529811, 5.397577095897295
# 24406     43.275516       5.426811     43.27551554346898, 5.426811010805492
# 24737     43.241727       5.374644    43.241727183196915, 5.374644362934933
# 29315     43.345502       5.394089     43.34550180669167, 5.394089157689507
# 29768     43.312696       5.363650    43.312696417763945, 5.363649832647911
# 30562     43.301413       0.213053    43.3014129982985, 0.21305255668099202
# 31041     43.488885       0.312582  43.488884847715354, 0.31258215129433803
# 31320     43.306733       5.400875     43.306733355015986, 5.40087488751533
# 31432     43.358795       5.363408     43.35879475399321, 5.363407896999305
# 31526     43.299901       5.382279     43.29990094363678, 5.382278697952185
# 36463     43.210633       2.548843    43.210633193537085, 2.548842525678497
#
#        DBL_coderegion                 DBL_nomregion
# 648                22                      PICARDIE
# 1012               24                        CENTRE
# 1474               93  "PROVENCE-ALPES-COTE D'AZUR"
# 2280               93  "PROVENCE-ALPES-COTE D'AZUR"
# 2320               93  "PROVENCE-ALPES-COTE D'AZUR"
# 5868               93  "PROVENCE-ALPES-COTE D'AZUR"
# 10395              93  "PROVENCE-ALPES-COTE D'AZUR"
# 12718              93  "PROVENCE-ALPES-COTE D'AZUR"
# 12724              91          LANGUEDOC-ROUSSILLON
# 16604              93  "PROVENCE-ALPES-COTE D'AZUR"
# 19675              93  "PROVENCE-ALPES-COTE D'AZUR"
# 23614              93  "PROVENCE-ALPES-COTE D'AZUR"
# 24406              93  "PROVENCE-ALPES-COTE D'AZUR"
# 24737              93  "PROVENCE-ALPES-COTE D'AZUR"
# 29315              93  "PROVENCE-ALPES-COTE D'AZUR"
# 29768              93  "PROVENCE-ALPES-COTE D'AZUR"
# 30562              73                 MIDI-PYRENEES
# 31041              73                 MIDI-PYRENEES
# 31320              93  "PROVENCE-ALPES-COTE D'AZUR"
# 31432              93  "PROVENCE-ALPES-COTE D'AZUR"
# 31526              93  "PROVENCE-ALPES-COTE D'AZUR"
# 36463              91          LANGUEDOC-ROUSSILLON

# %%
new_row = df2[df2['codecommune'] == '13201'].copy()

new_row['codecommune'] = '13055'
new_row['nomcommune'] = 'MARSEILLE*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)

# %%
df2[df2['codecommune'] == '13055']
# Out:
#       dep            nomdep codecommune  nomcommune  GEO_latitude  \
# 36742  13  BOUCHES-DU-RHONE       13055  MARSEILLE*     43.299901
#
#        GEO_longitude                      DBL_geo_point_2d  DBL_coderegion  \
# 36742       5.382279  43.29990094363678, 5.382278697952185              93
#
#                       DBL_nomregion
# 36742  "PROVENCE-ALPES-COTE D'AZUR"

# %% [markdown]
# ### ['55138', '69123', '69380', '75056', '76095', '76601']

# %%
# Culey
df2[df2['nomcommune'].str.startswith('CULEY')]
# Out:
#      dep    nomdep codecommune      nomcommune  GEO_latitude  GEO_longitude  \
# 8013  14  CALVADOS       14211  CULEY-LE-PATRY     48.956357      -0.531159
#
#                             DBL_geo_point_2d  DBL_coderegion    DBL_nomregion
# 8013  48.956357101639995, -0.531158873692519              25  BASSE-NORMANDIE

# %% [raw]
# Le code officiel géographique de la commune de Culey est 55138.
# Région : Grand Est (44) dont le chef-lieu est la commune de Strasbourg (67482)
# Département : Meuse (55) dont le chef-lieu est la commune de Bar-le-Duc (55029)
# Arrondissement : Bar-le-Duc (551) dont le chef-lieu est la commune de Bar-le-Duc (55029)
#
#     01/01/2014 : Culey est rétablie.
#     01/01/1973 : Culey est rattachée à Loisey (55298) qui devient Loisey-Culey (fusion simple).

# %%
df2[df2['codecommune'] == '55298']
# Out:
#       dep nomdep codecommune    nomcommune  GEO_latitude  GEO_longitude  \
# 11872  55  MEUSE       55298  LOISEY-CULEY     48.767348       5.283225
#
#                             DBL_geo_point_2d  DBL_coderegion DBL_nomregion
# 11872  48.76734769731965, 5.2832252610511095              41      LORRAINE

# %%
new_row = df2[df2['codecommune'] == '55298'].copy()

new_row['codecommune'] = '55138'
new_row['nomcommune'] = 'CULEY*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['nomcommune'].str.startswith('CULEY')]
# Out:
#       dep    nomdep codecommune      nomcommune  GEO_latitude  GEO_longitude  \
# 8013   14  CALVADOS       14211  CULEY-LE-PATRY     48.956357      -0.531159
# 36743  55     MEUSE       55138          CULEY*     48.767348       5.283225
#
#                              DBL_geo_point_2d  DBL_coderegion    DBL_nomregion
# 8013   48.956357101639995, -0.531158873692519              25  BASSE-NORMANDIE
# 36743   48.76734769731965, 5.2832252610511095              41         LORRAINE

# %% [markdown]
# ### ['69123', '69380', '75056', '76095', '76601']
#
#     Le code officiel géographique de la commune de Lyon est 69123.
#     Région : Auvergne-Rhône-Alpes (84) dont le chef-lieu est la commune de Lyon (69123)
#     Département : Rhône (69) dont le chef-lieu est la commune de Lyon (69123)
#     Arrondissement : Lyon (691) dont le chef-lieu est la commune de Lyon (69123)

# %%
df2[df2['nomcommune'].str.startswith('LYON')]
# Out:
#       dep nomdep codecommune                nomcommune  GEO_latitude  \
# 3790   69  RHONE       69384  LYON--4E--ARRONDISSEMENT     45.778687
# 4840   27   EURE       27377            LYONS-LA-FORET     49.393697
# 6551   69  RHONE       69386  LYON--6E--ARRONDISSEMENT     45.772851
# 11898  69  RHONE       69387  LYON--7E--ARRONDISSEMENT     45.733410
# 15129  69  RHONE       69389  LYON--9E--ARRONDISSEMENT     45.781781
# 18846  69  RHONE       69382  LYON--2E--ARRONDISSEMENT     45.749256
# 19347  69  RHONE       69381  LYON--1ER-ARRONDISSEMENT     45.769928
# 21982  69  RHONE       69388  LYON--8E--ARRONDISSEMENT     45.734203
# 32465  69  RHONE       69383  LYON--3E--ARRONDISSEMENT     45.753355
# 34509  69  RHONE       69385  LYON--5E--ARRONDISSEMENT     45.755832
#
#        GEO_longitude                        DBL_geo_point_2d  DBL_coderegion  \
# 3790        4.823961    45.77868675808076, 4.823961126890725              82
# 4840        1.473559      49.3936970778067, 1.47355856777582              23
# 6551        4.852079  45.772850723857935, 4.8520791143730015              82
# 11898       4.837585   45.733409841520235, 4.837584957030807              82
# 15129       4.808183   45.781780588731166, 4.808183278224059              82
# 18846       4.826170     45.74925603938733, 4.82617032549066              82
# 19347       4.829225    45.76992843965841, 4.829224649781766              82
# 21982       4.869357    45.73420346909841, 4.869357223053562              82
# 32465       4.869185     45.7533552486214, 4.869185220128738              82
# 34509       4.802254     45.7558317848881, 4.802253694897703              82
#
#          DBL_nomregion
# 3790       RHONE-ALPES
# 4840   HAUTE-NORMANDIE
# 6551       RHONE-ALPES
# 11898      RHONE-ALPES
# 15129      RHONE-ALPES
# 18846      RHONE-ALPES
# 19347      RHONE-ALPES
# 21982      RHONE-ALPES
# 32465      RHONE-ALPES
# 34509      RHONE-ALPES

# %%
new_row = df2[df2['codecommune'] == '69381'].copy()

new_row['codecommune'] = '69123'
new_row['nomcommune'] = 'LYON*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['nomcommune'].str.startswith('LYON*')]
# Out:
#       dep nomdep codecommune nomcommune  GEO_latitude  GEO_longitude  \
# 36744  69  RHONE       69123      LYON*     45.769928       4.829225
#
#                            DBL_geo_point_2d  DBL_coderegion DBL_nomregion
# 36744  45.76992843965841, 4.829224649781766              82   RHONE-ALPES

# %% [markdown]
# ### ['69380', '75056', '76095', '76601']
#
# NON TROUVE CODE POSTAL
# Code postal de Marcilly-d'Azergues
# 69380
# Population en 2012
# 900 Marcillois
# Code INSEE
# 69125

# %%
df2[df2['codecommune'] == '69125']
# Out:
#       dep nomdep codecommune           nomcommune  GEO_latitude  \
# 30097  69  RHONE       69125  MARCILLY-D'AZERGUES     45.867988
#
#        GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 30097       4.730916  45.867988264542596, 4.730916110175073              82
#
#       DBL_nomregion
# 30097   RHONE-ALPES

# %%
new_row = df2[df2['codecommune'] == '69125'].copy()

new_row['codecommune'] = '69380'
new_row['nomcommune'] = 'Non Renseigne*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['codecommune'] == '69380']
# Out:
#       dep nomdep codecommune      nomcommune  GEO_latitude  GEO_longitude  \
# 36745  69  RHONE       69380  Non Renseigne*     45.867988       4.730916
#
#                             DBL_geo_point_2d  DBL_coderegion DBL_nomregion
# 36745  45.867988264542596, 4.730916110175073              82   RHONE-ALPES

# %% [markdown]
# ### ['75056', '76095', '76601']

# %%
df2[df2['nomcommune'].str.startswith('PARIS-')]
# Out:
#       dep          nomdep codecommune                nomcommune  GEO_latitude  \
# 322    75           PARIS       75110  PARIS-10E-ARRONDISSEMENT     48.876029
# 436    75           PARIS       75116  PARIS-16E-ARRONDISSEMENT     48.860399
# 2433   75           PARIS       75109   PARIS-9E-ARRONDISSEMENT     48.876896
# 3822   75           PARIS       75115  PARIS-15E-ARRONDISSEMENT     48.840155
# 6744   75           PARIS       75102   PARIS-2E-ARRONDISSEMENT     48.867903
# 6819   75           PARIS       75111  PARIS-11E-ARRONDISSEMENT     48.859415
# 9988   71  SAONE-ET-LOIRE       71343           PARIS-L'HOPITAL     46.912789
# 13566  75           PARIS       75118  PARIS-18E-ARRONDISSEMENT     48.892735
# 14296  75           PARIS       75105   PARIS-5E-ARRONDISSEMENT     48.844509
# 19937  75           PARIS       75108   PARIS-8E-ARRONDISSEMENT     48.872527
# 20560  75           PARIS       75113  PARIS-13E-ARRONDISSEMENT     48.828718
# 20779  75           PARIS       75112  PARIS-12E-ARRONDISSEMENT     48.835156
# 22557  75           PARIS       75101  PARIS-1ER-ARRONDISSEMENT     48.862630
# 26173  75           PARIS       75117  PARIS-17E-ARRONDISSEMENT     48.887337
# 26467  75           PARIS       75104   PARIS-4E-ARRONDISSEMENT     48.854228
# 29510  75           PARIS       75119  PARIS-19E-ARRONDISSEMENT     48.886869
# 29579  75           PARIS       75120  PARIS-20E-ARRONDISSEMENT     48.863187
# 29853  75           PARIS       75107   PARIS-7E-ARRONDISSEMENT     48.856083
# 33654  75           PARIS       75103   PARIS-3E-ARRONDISSEMENT     48.863054
# 34023  75           PARIS       75106   PARIS-6E-ARRONDISSEMENT     48.848968
# 36683  75           PARIS       75114  PARIS-14E-ARRONDISSEMENT     48.828993
#
#        GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 322         2.361113   48.87602855694339, 2.361112904561707              11
# 436         2.262100   48.86039876035177, 2.262099559395783              11
# 2433        2.337460   48.87689616237872, 2.337460241388529              11
# 3822        2.293559   48.84015541860987, 2.293559372435076              11
# 6744        2.344107   48.86790337886785, 2.344107166658533              11
# 6819        2.378741   48.85941549762748, 2.378741060237548              11
# 9988        4.639586  46.912788557458065, 4.639585731456624              26
# 13566       2.348712  48.892735074561706, 2.348711933867703              11
# 14296       2.349859  48.844508659617546, 2.349859385560182              11
# 19937       2.312583   48.87252726662346, 2.312582560420059              11
# 20560       2.362468   48.82871768452136, 2.362468228516128              11
# 20779       2.419807   48.83515623066034, 2.419807034965275              11
# 22557       2.336293    48.8626304851685, 2.336293446550539              11
# 26173       2.307486   48.88733716648682, 2.307485559493426              11
# 26467       2.357362  48.854228281954754, 2.357361938142205              11
# 29510       2.384694   48.88686862295828, 2.384694327870042              11
# 29579       2.400820   48.86318677744551, 2.400819826729021              11
# 29853       2.312439   48.85608259819694, 2.312438687733857              11
# 33654       2.359361   48.86305413181178, 2.359361058970589              11
# 34023       2.332671   48.84896809191946, 2.332670898588416              11
# 36683       2.327101   48.82899321160942, 2.327100883257538              11
#
#        DBL_nomregion
# 322    ILE-DE-FRANCE
# 436    ILE-DE-FRANCE
# 2433   ILE-DE-FRANCE
# 3822   ILE-DE-FRANCE
# 6744   ILE-DE-FRANCE
# 6819   ILE-DE-FRANCE
# 9988       BOURGOGNE
# 13566  ILE-DE-FRANCE
# 14296  ILE-DE-FRANCE
# 19937  ILE-DE-FRANCE
# 20560  ILE-DE-FRANCE
# 20779  ILE-DE-FRANCE
# 22557  ILE-DE-FRANCE
# 26173  ILE-DE-FRANCE
# 26467  ILE-DE-FRANCE
# 29510  ILE-DE-FRANCE
# 29579  ILE-DE-FRANCE
# 29853  ILE-DE-FRANCE
# 33654  ILE-DE-FRANCE
# 34023  ILE-DE-FRANCE
# 36683  ILE-DE-FRANCE

# %%
# 75101
new_row = df2[df2['codecommune'] == '75101'].copy()

new_row['codecommune'] = '75056'
new_row['nomcommune'] = 'PARIS*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['codecommune'] == '75056']
# Out:
#       dep nomdep codecommune nomcommune  GEO_latitude  GEO_longitude  \
# 36746  75  PARIS       75056     PARIS*      48.86263       2.336293
#
#                           DBL_geo_point_2d  DBL_coderegion  DBL_nomregion
# 36746  48.8626304851685, 2.336293446550539              11  ILE-DE-FRANCE

# %% [markdown]
# ### ['76095', '76601']
# Bihorel
#
#
#     01/01/2014 : Bihorel est rétablie.
#     01/01/2012 : Bihorel devient commune déléguée au sein de Bois-Guillaume-Bihorel (76108) (commune nouvelle).

# %%
df2[df2['codecommune'] == '76108']
# Out:
#      dep          nomdep codecommune              nomcommune  GEO_latitude  \
# 9348  76  SEINE-MARITIME       76108  BOIS-GUILLAUME-BIHOREL     49.471762
#
#       GEO_longitude                      DBL_geo_point_2d  DBL_coderegion  \
# 9348       1.120226  49.471761571405764, 1.12022637351156              23
#
#         DBL_nomregion
# 9348  HAUTE-NORMANDIE

# %%
new_row = df2[df2['codecommune'] == '76108'].copy()

new_row['codecommune'] = '76095'
new_row['nomcommune'] = 'BIHOREL*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['codecommune'] == '76095']
# Out:
#       dep          nomdep codecommune nomcommune  GEO_latitude  GEO_longitude  \
# 36747  76  SEINE-MARITIME       76095   BIHOREL*     49.471762       1.120226
#
#                            DBL_geo_point_2d  DBL_coderegion    DBL_nomregion
# 36747  49.471761571405764, 1.12022637351156              23  HAUTE-NORMANDIE

# %% [markdown]
# ### ['76601']
#
# Saint-Lucien
# Le code officiel géographique de la commune de Saint-Lucien est 76601.
# Région : Normandie (28) dont le chef-lieu est la commune de Rouen (76540)
# Département : Seine-Maritime (76) dont le chef-lieu est la commune de Rouen (76540)
# Arrondissement : Dieppe (761) dont le chef-lieu est la commune de Dieppe (76217)
#
#
#     01/01/2017 : Saint-Lucien est rétablie.
#     01/06/1973 : Saint-Lucien est rattachée à Sigy-en-Bray (76676) (fusion association).

# %%
df2[df2['nomcommune'].str.startswith('SAINT-LUCIEN')]
# Out:
#       dep        nomdep codecommune    nomcommune  GEO_latitude  \
# 22157  28  EURE-ET-LOIR       28349  SAINT-LUCIEN     48.639163
#
#        GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 22157       1.623309  48.63916266127105, 1.6233092495116521              24
#
#       DBL_nomregion
# 22157        CENTRE

# %%
df2[df2['codecommune'] == '76676']
# Out:
#      dep          nomdep codecommune    nomcommune  GEO_latitude  \
# 5117  76  SEINE-MARITIME       76676  SIGY-EN-BRAY     49.533563
#
#       GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 5117       1.466921  49.53356288523321, 1.4669213469817501              23
#
#         DBL_nomregion
# 5117  HAUTE-NORMANDIE

# %%
new_row = df2[df2['codecommune'] == '76676'].copy()

new_row['codecommune'] = '76601'
new_row['nomcommune'] = 'SAINT-LUCIEN*'

# Concatenate the original DataFrame with the new row
df2 = pd.concat([df2, new_row], ignore_index=True)
df2[df2['codecommune'] == '76601']
# Out:
#       dep          nomdep codecommune     nomcommune  GEO_latitude  \
# 36748  76  SEINE-MARITIME       76601  SAINT-LUCIEN*     49.533563
#
#        GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 36748       1.466921  49.53356288523321, 1.4669213469817501              23
#
#          DBL_nomregion
# 36748  HAUTE-NORMANDIE

# %%
codecommune_listdf2_corr = df2['codecommune'].tolist()

# %%
absent = [x for x in lines if x not in codecommune_listdf2_corr]

# %%
len(absent)
# Out:
# 0

# %%
df2[df2['nomcommune'].str.endswith('*')]
# Out:
#       dep            nomdep codecommune      nomcommune  GEO_latitude  \
# 36742  13  BOUCHES-DU-RHONE       13055      MARSEILLE*     43.299901
# 36743  55             MEUSE       55138          CULEY*     48.767348
# 36744  69             RHONE       69123           LYON*     45.769928
# 36745  69             RHONE       69380  Non Renseigne*     45.867988
# 36746  75             PARIS       75056          PARIS*     48.862630
# 36747  76    SEINE-MARITIME       76095        BIHOREL*     49.471762
# 36748  76    SEINE-MARITIME       76601   SAINT-LUCIEN*     49.533563
#
#        GEO_longitude                       DBL_geo_point_2d  DBL_coderegion  \
# 36742       5.382279   43.29990094363678, 5.382278697952185              93
# 36743       5.283225  48.76734769731965, 5.2832252610511095              41
# 36744       4.829225   45.76992843965841, 4.829224649781766              82
# 36745       4.730916  45.867988264542596, 4.730916110175073              82
# 36746       2.336293    48.8626304851685, 2.336293446550539              11
# 36747       1.120226   49.471761571405764, 1.12022637351156              23
# 36748       1.466921  49.53356288523321, 1.4669213469817501              23
#
#                       DBL_nomregion
# 36742  "PROVENCE-ALPES-COTE D'AZUR"
# 36743                      LORRAINE
# 36744                   RHONE-ALPES
# 36745                   RHONE-ALPES
# 36746                 ILE-DE-FRANCE
# 36747               HAUTE-NORMANDIE
# 36748               HAUTE-NORMANDIE

# %%
df2['DBL_bug'] = df2['nomcommune'].str.endswith('*').astype(int)
df2.head(5)
# Out:
#   dep           nomdep codecommune     nomcommune  GEO_latitude  \
# 0  59             NORD       59416      MORBECQUE     50.676893
# 1  22  "COTES-D'ARMOR"       22102      LANGOURLA     48.284641
# 2  31    HAUTE-GARONNE       31225  GOUTEVERNISSE     43.214026
# 3  23           CREUSE       23025         BONNAT     46.323019
# 4  38            ISERE       38522    VALJOUFFREY     44.881535
#
#    GEO_longitude                        DBL_geo_point_2d  DBL_coderegion  \
# 0       2.536216    50.67689342861573, 2.536216144331492              31
# 1      -2.415501  48.284641107667674, -2.415501011324659              53
# 2       1.173766   43.214026301449536, 1.173765920286677              73
# 3       1.913451    46.32301933418213, 1.913450631364578              74
# 4       6.079504     44.88153491127053, 6.07950399615059              82
#
#         DBL_nomregion  DBL_bug
# 0  NORD-PAS-DE-CALAIS        0
# 1            BRETAGNE        0
# 2       MIDI-PYRENEES        0
# 3            LIMOUSIN        0
# 4         RHONE-ALPES        0

# %% [markdown]
# ## <a name="TRANSCO"></a>Partie 3 : Filtres et/ou calculs&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#TOP">&uarr;</a>

# %%
len(lines)
# Out:
# 33830

# %%
len(df2)
# Out:
# 36749

# %%
df2_filtered = df2[df2['codecommune'].isin(lines)]
df2_filtered.shape
# Out:
# (33830, 10)

# %% [markdown]
# ## <a name="EXPORT"></a>Partie 4 : EXPORT&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<a href="#TOP">&uarr;</a>
# - ../DATA/EXPORT_CSV/
# - final
# - GEO
# - correspondance-code-insee-code-postal.csv
#
# Attention : sources CSV dans Others

# %%
path_export='../DATA/EXPORT_CSV/final_GEO_correspondance-code-insee-code-postal.csv'

# %%
df2_filtered.to_csv(path_export, sep=';', index=False)

print(f'DataFrame exported to: {path_export}')
# Out:
# DataFrame exported to: ../DATA/EXPORT_CSV/final_GEO_correspondance-code-insee-code-postal.csv
